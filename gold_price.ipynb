# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('C:\\Users\\subba\\Downloads\\Untitled spreadsheet - Sheet1 (1).csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#          Date   22k     24k     18k  Silver  Platinum
# 0  20-02-2024  5735  6256.0  4692.0     NaN       NaN
# 1  21-02-2024  5745  6272.0  4704.0    77.5    3255.0
# 2  22-02-2024  5760  6288.0  4716.0    77.2    3270.0
# 3  23-02-2024  5760  6288.0  4716.0    76.0    3281.0
# 4  24-02-2024  5760  6288.0  4716.0    75.5    3220.0

# %%
df
# Out:
#           Date   22k     24k     18k  Silver  Platinum
# 0   20-02-2024  5735  6256.0  4692.0     NaN       NaN
# 1   21-02-2024  5745  6272.0  4704.0    77.5    3255.0
# 2   22-02-2024  5760  6288.0  4716.0    77.2    3270.0
# 3   23-02-2024  5760  6288.0  4716.0    76.0    3281.0
# 4   24-02-2024  5760  6288.0  4716.0    75.5    3220.0
# ..         ...   ...     ...     ...     ...       ...
# 65  22-05-2024  6830  7456.0  5595.0   100.3    3827.0
# 66  20-05-2024  6890  7522.0  5641.0   101.0       NaN
# 67  17-05-2024  6760  7380.0  5535.0    92.5    3806.0
# 68  18-05-2024  6840     NaN     NaN     NaN    3850.0
# 69  16-05-2024  6785  7407.0  5555.0    92.5       NaN
#
# [70 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Date', '22k', '24k', '18k', 'Silver', 'Platinum'], dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sorting the DataFrame by Date
df_sorted = df.sort_values(by='Date')

# Display the sorted DataFrame
print(df_sorted)
# Out:
#          Date   22k     24k     18k  Silver  Platinum
# 0  2024-02-20  5735  6256.0  4692.0     NaN       NaN
# 1  2024-02-21  5745  6272.0  4704.0    77.5    3255.0
# 2  2024-02-22  5760  6288.0  4716.0    77.2    3270.0
# 3  2024-02-23  5760  6288.0  4716.0    76.0    3281.0
# 4  2024-02-24  5760  6288.0  4716.0    75.5    3220.0
# ..        ...   ...     ...     ...     ...       ...
# 30 2024-07-23  6745  7364.0  5523.0    95.6    3522.0
# 29 2024-07-25  6400  6987.0  5240.0    89.0    3472.0
# 28 2024-07-26  6400  6987.0  5240.0    89.0    3500.0
# 27 2024-07-29  6340  6921.0  5191.0    89.5    3424.0
# 26 2024-07-30  6320  6900.0  5175.0    89.0    3169.0
#
# [70 rows x 6 columns]

# %%
df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      70 non-null     datetime64[ns]
#  1   22k       70 non-null     int64
#  2   24k       68 non-null     float64
#  3   18k       68 non-null     float64
#  4   Silver    65 non-null     float64
#  5   Platinum  61 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 3.8 KB

# %%
df_filled = df.fillna(df.mean(numeric_only=True))

# Display the DataFrame with filled values
print(df_filled)
# Out:
#          Date   22k          24k          18k      Silver     Platinum
# 0  2024-02-20  5735  6256.000000  4692.000000   91.597692  3522.344262
# 1  2024-02-21  5745  6272.000000  4704.000000   77.500000  3255.000000
# 2  2024-02-22  5760  6288.000000  4716.000000   77.200000  3270.000000
# 3  2024-02-23  5760  6288.000000  4716.000000   76.000000  3281.000000
# 4  2024-02-24  5760  6288.000000  4716.000000   75.500000  3220.000000
# ..        ...   ...          ...          ...         ...          ...
# 65 2024-05-22  6830  7456.000000  5595.000000  100.300000  3827.000000
# 66 2024-05-20  6890  7522.000000  5641.000000  101.000000  3522.344262
# 67 2024-05-17  6760  7380.000000  5535.000000   92.500000  3806.000000
# 68 2024-05-18  6840  7102.911765  5327.470588   91.597692  3850.000000
# 69 2024-05-16  6785  7407.000000  5555.000000   92.500000  3522.344262
#
# [70 rows x 6 columns]

# %%
df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      70 non-null     datetime64[ns]
#  1   22k       70 non-null     int64
#  2   24k       70 non-null     float64
#  3   18k       70 non-null     float64
#  4   Silver    70 non-null     float64
#  5   Platinum  70 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 3.4 KB

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')


df_melted = df.melt('Date', var_name='Metal', value_name='Price')


plt.figure(figsize=(10, 6))
sns.lineplot(data=df_melted, x='Date', y='Price', hue='Metal', marker='o')


plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Price Trends for Different Metals (Seaborn)')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import seaborn as sns

# Bar Plot using Seaborn
df['Month-Year'] = df['Date'].dt.to_period('M')
df_grouped = df.groupby('Month-Year').mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Month-Year', y='24k', data=df_grouped)
plt.xlabel('Month-Year')
plt.ylabel('Average Price of 24k Gold')
plt.title('Average Price of 24k Gold by Month (Bar Plot)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Bar Plot using Seaborn
df['Month-Year'] = df['Date'].dt.to_period('M')
df_grouped = df.groupby('Month-Year').mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Month-Year', y='22k', data=df_grouped)
plt.xlabel('Month-Year')
plt.ylabel('Average Price of 22k Gold')
plt.title('Average Price of 22k Gold by Month (Bar Plot)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Bar Plot using Seaborn
df['Month-Year'] = df['Date'].dt.to_period('M')
df_grouped = df.groupby('Month-Year').mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Month-Year', y='Silver', data=df_grouped)
plt.xlabel('Month-Year')
plt.ylabel('Average Price of Silver')
plt.title('Average Price of Silver  by Month (Bar Plot)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Box Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['22k', '24k', '18k']])
plt.xlabel('Metal Type')
plt.ylabel('Price')
plt.title('Box Plot of Gold Prices')
plt.tight_layout()
plt.show()

# %%
# Box Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['22k', 'Silver', 'Platinum']])
plt.xlabel('Metal Type')
plt.ylabel('Price')
plt.title('Box Plot of Gold Prices')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot using Matplotlib
plt.figure(figsize=(10, 6))
plt.scatter(df['22k'], df['24k'], c='blue', marker='o')
plt.xlabel('22k Gold Price')
plt.ylabel('24k Gold Price')
plt.title('Scatter Plot of 22k vs 24k Gold Prices')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot using Matplotlib
plt.figure(figsize=(10, 6))
plt.scatter(df['22k'], df['Silver'], c='blue', marker='o')
plt.xlabel('22k Gold Price')
plt.ylabel('Silver Price')
plt.title('Scatter Plot of 22k vs Silver Prices')
plt.tight_layout()

# Show the plot
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        70 non-null     datetime64[ns]
#  1   22k         70 non-null     int64
#  2   24k         68 non-null     float64
#  3   18k         68 non-null     float64
#  4   Silver      65 non-null     float64
#  5   Platinum    61 non-null     float64
#  6   Month-Year  70 non-null     period[M]
# dtypes: datetime64[ns](1), float64(4), int64(1), period[M](1)
# memory usage: 4.0 KB

# %%
df[]
# Out:
#   Cell In[50], line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
df_filled.columns
# Out:
# Index(['Date', '22k', '24k', '18k', 'Silver', 'Platinum'], dtype='object')

# %%
df_filled[['22k', '24k', '18k', 'Silver', 'Platinum']].corr()
# Out:
#                22k       24k       18k    Silver  Platinum
# 22k       1.000000  0.988100  0.988092  0.816158  0.708870
# 24k       0.988100  1.000000  0.999985  0.825080  0.680177
# 18k       0.988092  0.999985  1.000000  0.825821  0.680736
# Silver    0.816158  0.825080  0.825821  1.000000  0.803752
# Platinum  0.708870  0.680177  0.680736  0.803752  1.000000

# %%
df_filled['Date'] = pd.to_datetime(df_filled['Date'])


df_filled['Difference'] = df_filled['24k'] - df_filled['Silver']


print(df_filled)
# Out:
#          Date   22k          24k          18k      Silver     Platinum  \
# 0  2024-02-20  5735  6256.000000  4692.000000   91.597692  3522.344262
# 1  2024-02-21  5745  6272.000000  4704.000000   77.500000  3255.000000
# 2  2024-02-22  5760  6288.000000  4716.000000   77.200000  3270.000000
# 3  2024-02-23  5760  6288.000000  4716.000000   76.000000  3281.000000
# 4  2024-02-24  5760  6288.000000  4716.000000   75.500000  3220.000000
# ..        ...   ...          ...          ...         ...          ...
# 65 2024-05-22  6830  7456.000000  5595.000000  100.300000  3827.000000
# 66 2024-05-20  6890  7522.000000  5641.000000  101.000000  3522.344262
# 67 2024-05-17  6760  7380.000000  5535.000000   92.500000  3806.000000
# 68 2024-05-18  6840  7102.911765  5327.470588   91.597692  3850.000000
# 69 2024-05-16  6785  7407.000000  5555.000000   92.500000  3522.344262
#
#      Difference
# 0   6164.402308
# 1   6194.500000
# 2   6210.800000
# 3   6212.000000
# 4   6212.500000
# ...

# %%
df_filled.describe()
# Out:
#                                 Date          22k          24k          18k  \
# count                             70    70.000000    70.000000    70.000000
# mean   2024-05-20 18:30:51.428571392  6514.857143  7102.911765  5327.470588
# min              2024-02-20 00:00:00  5735.000000  6256.000000  4692.000000
# 25%              2024-04-06 18:00:00  6370.000000  6954.000000  5215.250000
# 50%              2024-05-28 12:00:00  6635.000000  7240.500000  5433.000000
# 75%              2024-07-01 18:00:00  6745.000000  7334.750000  5501.000000
# max              2024-07-30 00:00:00  6890.000000  7522.000000  5641.000000
# std                              NaN   323.329566   349.142541   261.885663
#
#            Silver     Platinum   Difference
# count   70.000000    70.000000    70.000000
# mean    91.597692  3522.344262  7011.314072
# min     75.500000  3169.000000  6164.402308
# 25%     88.250000  3381.250000  6870.550000
# 50%     94.600000  3522.344262  7144.450000
# ...

# %%
# Extract month and year from the Date column
df_filled['YearMonth'] = df_filled['Date'].dt.to_period('M')

# Group by YearMonth and calculate min, max, and mean of the Difference column
monthly_summary = df_filled.groupby('YearMonth')['Difference'].agg(['min', 'max', 'mean'])

# Display the results
print(monthly_summary)
# Out:
#                    min      max         mean
# YearMonth
# 2024-02    6164.402308  6212.50  6198.840462
# 2024-03    6337.000000  6655.50  6534.100462
# 2024-04    6861.400000  7339.00  7145.440000
# 2024-05    7011.314072  7421.00  7242.601279
# 2024-06    7076.000000  7279.50  7152.280000
# 2024-07    6811.000000  7342.25  7160.503372

# %%
def get_extreme_dates(group):
    max_diff_date = group.loc[group['Difference'].idxmax(), 'Date']
    min_diff_date = group.loc[group['Difference'].idxmin(), 'Date']
    return pd.Series({
        'MaxDifference': group['Difference'].max(),
        'MaxDifferenceDate': max_diff_date,
        'MinDifference': group['Difference'].min(),
        'MinDifferenceDate': min_diff_date
    })

# Group by YearMonth and apply the function
monthly_summary = df_filled.groupby('YearMonth').apply(get_extreme_dates)

# Display the results
print(monthly_summary)
# Out:
#            MaxDifference MaxDifferenceDate  MinDifference MinDifferenceDate
# YearMonth
# 2024-02          6212.50        2024-02-24    6164.402308        2024-02-20
# 2024-03          6655.50        2024-03-28    6337.000000        2024-03-04
# 2024-04          7339.00        2024-04-21    6861.400000        2024-04-01
# 2024-05          7421.00        2024-05-20    7011.314072        2024-05-18
# 2024-06          7279.50        2024-06-07    7076.000000        2024-06-08
# 2024-07          7342.25        2024-07-19    6811.000000        2024-07-30
# C:\Users\subba\AppData\Local\Temp\ipykernel_40136\1867600570.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %%
correlation = df_filled['Silver'].corr(df_filled['24k'])
print(correlation)
# Out:
# 0.8250803359390263

# %%
from sklearn.linear_model import LinearRegression
X = df_filled[['Silver']]
y = df_filled['24k']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Predict gold price for a new silver price
new_silver_price = 26.00
predicted_gold_price = model.predict(np.array([[new_silver_price]]))
print(f"Predicted Gold Price for Silver Price of {new_silver_price}: {predicted_gold_price[0]:.2f}")
# Out:
# Predicted Gold Price for Silver Price of 26.0: 4535.18
# C:\Users\subba\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Assuming df_filled is your DataFrame with 'Silver' and '24k' columns
X = df_filled[['Date','Silver']]
y = df_filled['24k']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Predict gold price for a new silver price
new_silver_price = 26.00
new_date='2024-08-17'
predicted_gold_price = model.predict(np.array([[new_date,new_silver_price]]))
print(f"Predicted Gold Price for Silver Price of {new_silver_price}: {predicted_gold_price[0]:.2f}")
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[59], line 11
#       9 # Initialize and train the model
#      10 model = LinearRegression()
# ---> 11 model.fit(X, y)
#      13 # Predict gold price for a new silver price
#      14 new_silver_price = 26.00
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from datetime import datetime

# Assuming df_filled is your DataFrame with 'Silver' and '24k' columns
X = df_filled[['Silver']]
y = df_filled['24k']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Predict gold price for a new silver price
new_silver_price = 89
predicted_gold_price = model.predict(np.array([[new_silver_price]]))

# Get today's date
today_date = datetime.now().strftime('%Y-%m-%d')

# Print prediction with today's date
print(f"Prediction Date: {today_date}")
print(f"Predicted Gold Price for Silver Price of {new_silver_price}: {predicted_gold_price[0]:.2f}")
# Out:
# Prediction Date: 2024-09-27
# Predicted Gold Price for Silver Price of 89: 7001.23
# C:\Users\subba\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from datetime import datetime

# Assuming df_filled is your DataFrame with 'Silver' and '24k' columns
X = df_filled[['Silver']]
y = df_filled['22k']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Predict gold price for a new silver price
new_silver_price = 91
predicted_gold_price = model.predict(np.array([[new_silver_price]]))

# Get today's date
today_date = datetime.now().strftime('%Y-%m-%d')

# Print prediction with today's date
print(f"Prediction Date: {today_date}")
print(f"Predicted Gold Price for Silver Price of {new_silver_price}: {predicted_gold_price[0]:.2f}")
# Out:
# Prediction Date: 2024-09-27
# Predicted Gold Price for Silver Price of 91: 6493.43
# C:\Users\subba\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from datetime import datetime

# Assuming df_filled is your DataFrame with 'Silver' and '24k' columns
X = df_filled[['Silver']]
y = df_filled['24k']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Predict gold price for a new silver price
new_silver_price = 91
predicted_gold_price = model.predict(np.array([[new_silver_price]]))

# Get today's date
today_date = datetime.now().strftime('%Y-%m-%d')

# Print prediction with today's date
print(f"Prediction Date: {today_date}")
print(f"Predicted Gold Price for Silver Price of {new_silver_price}: {predicted_gold_price[0]:.2f}")
# Out:
# Prediction Date: 2024-09-27
# Predicted Gold Price for Silver Price of 91: 7079.52
# C:\Users\subba\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from datetime import datetime

# Assuming df_filled is your DataFrame with 'Silver' and '24k' columns
df_filled['Date'] = pd.to_datetime(df_filled['Date'])
df_filled['Year'] = df_filled['Date'].dt.year
df_filled['Month'] = df_filled['Date'].dt.month
df_filled['Day'] = df_filled['Date'].dt.day

# Define features and target
X = df_filled[['Silver', 'Year', 'Month', 'Day']]
y = df_filled['22k']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

new_silver_price = 93
new_date = pd.to_datetime('2024-08-24')
new_features = pd.DataFrame({
    'Silver': [new_silver_price],
    'Year': [new_date.year],
    'Month': [new_date.month],
    'Day': [new_date.day]
})

predicted_gold_price = model.predict(new_features)
print(f"Predicted Gold Price for Silver Price of {new_silver_price} on {new_date.date()}: {predicted_gold_price[0]:.2f}")
# Out:
# Predicted Gold Price for Silver Price of 93 on 2024-08-24: 6700.62
